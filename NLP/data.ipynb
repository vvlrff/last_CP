# %%
import pandas as pd
from sklearn.model_selection import train_test_split
pd.set_option('display.max_colwidth', None)

# %%
data = pd.read_csv("train_dataset_train.csv", delimiter=";")
data = data.rename(columns={'Исполнитель':'executor', 'Группа тем': 'topic_group', 'Текст инцидента':'text', 'Тема': 'topic'})

# %%
data.shape
# Out:
# (23128, 4)

# %%
data.head(20)
# Out:
#                                          executor  \
# 0                     Лысьвенский городской округ
# 1            Министерство социального развития ПК
# 2            Министерство социального развития ПК
# 3                                     Город Пермь
# 4                    Министерство здравоохранения
# 5                                      АО ПРО ТКО
# 6                        Министерство образования
# 7                    Министерство здравоохранения
# 8                    Министерство здравоохранения
# 9                                         ИГЖН ПК
# 10                   Министерство здравоохранения
# 11           Министерство социального развития ПК
# 12           Министерство социального развития ПК
# 13  Бардымский муниципальный округ Пермского края
# 14           Министерство социального развития ПК
# 15                   Министерство здравоохранения
# 16                                    Город Пермь
# 17           Министерство социального развития ПК
# 18                                        ИГЖН ПК
# 19           Министерство социального развития ПК
#
#                          topic_group  \
# 0                    Благоустройство
# 1   Социальное обслуживание и защита
# 2   Социальное обслуживание и защита
# 3             Общественный транспорт
# 4           Здравоохранение/Медицина
# 5                   Мусор/Свалки/ТКО
# 6                        Образование
# 7           Здравоохранение/Медицина
# 8           Здравоохранение/Медицина
# 9                             Дороги
# 10          Здравоохранение/Медицина
# 11  Социальное обслуживание и защита
# 12  Социальное обслуживание и защита
# 13                   Благоустройство
# 14  Социальное обслуживание и защита
# 15          Здравоохранение/Медицина
# 16  Социальное обслуживание и защита
# 17  Социальное обслуживание и защита
# 18                   Благоустройство
# 19  Социальное обслуживание и защита
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            text  \
# 0                                                                                                                                            'Добрый день. Сегодня, 20.08.22, моя мать шла по улице Ленина между домами 96 и 94. Фонари не горят, упала в яму, которую не видно. Сильно ударилась, остались синяки, очень больно. Благо шла не одна.<br>Уважаемая Администрация, сделайте с этим что-нибудь, да и не только с этим. Ходить опасно не только взрослым, но и детям. Если бы упал маленький ребёнок, было бы намного хуже. Фото прилагаю. Спасибо!
# 1                                                                                                                                                                                                                                                                                               'Пермь г, +79194692145. В Перми с ноября 2021 года не работает социальное такси. Каким образом можно получить льготу по проезду в такси в соц учреждения инвалиду 2гр.пррезд в общественном транспорте не возможен. Да и проездного льготного не представляется
# 2                                                                                                                                                                                                                                                                                                                                                                                                                          'Добрый день ! Скажите пожалуйста если подовала на пособие с 3 до 7 2 декабря , когда можно повторно подать ? вроде за 30 дней можно
# 3                                                                                                      'Каждая из них не о чем. Люди на остановках хотят укрыться от непогоды или слишком погоды. Присесть, поставить сумку. Лавочки на полторы попы? Отсутствие или намек на присутствие спинки? Конструкторы, понятно, что не ждут транспорт на остановках. А гаджеты заряжать дома надо. Интерактивные панели и близко не нужны. У каждого в руках телефоны- информации вагон. Разместить коды для быстрого доступа на ресурсы и сайты по транспорту хватит.
# 4                                                                                                                                                                                                                                                                'В Березниках у сына привитого откоронавируса заболел пытались попасть на прием очередь в замкнутом пространстве бесподобна прямое вредителбское отношение к людям он не смог попасть на прием что делать на работу с т - ой 37.8 не пускают и на прием не попасть .что вы мин здрав ДЕЛАЕТЕ ?
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   'Добрый день!подскажите тариф повысился на обращение с тко?
# 6                                                                                                                                                                                                                                                                                                                                                                                     'Здравствуйте, уточните в какую погоду дети начальной школы должны заниматься весной и осенью на улице ? Какие ограничения по температурному режиму и погодным условиям ?
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  '
# 19                                                                                                                                                                                                                                                                                                                                                                                 'Здравствуйте! Подскажите пожалуйста, за какой период нужно взять справку из школы, если я буду подавать в марте на губернаторские до 3 лет на третьего и последующих детей?
#
#                                                                                                               topic
# 0                                                                                                   ★ Ямы во дворах
# 1                                                                                         Оказание гос. соц. помощи
# 2                                                                                          Дети и многодетные семьи
# 3                                                                                              Содержание остановок
# 4                                                                   Технические проблемы с записью на прием к врачу
# 5                                                                                                Плата за вывоз ТКО
# 6                                                                                           Образовательный процесс
# 7                                                                                                   Диспансеризация
# 8                                                                                               ★ Просьбы о лечении
# 9   ★ Нарушение правил очистки дорог от снега и наледи/Обращения о необходимости очистить тротуар от снега и наледи
# 10                                                                                              ★ Просьбы о лечении
# 11                                                                                        Оказание гос. соц. помощи
# 12                                                                                        Оказание гос. соц. помощи
# 13                                                                                   Предложение по благоустройству
# 14                                                                                        Задержка выплат гражданам
# 15                                                                  Технические проблемы с записью на прием к врачу
# 16                                                                                      Аварийное жилье/переселение
# 17                                                                                         Дети и многодетные семьи
# 18                           ★ Нарушение правил уборки от снега и наледи внутридворового проезда, тротуара, площади
# 19                                                                                        Оказание гос. соц. помощи

# %%
topic_group = list(data.topic_group.unique())

# %%
len(topic_group)
# Out:
# 26

# %%
topic_group_with_nums = dict(enumerate(topic_group))
topic_group_with_nums = dict((v,k) for k,v in topic_group_with_nums.items())

# %%
topic_group_with_nums
# Out:
# {'Благоустройство': 0,
#  'Социальное обслуживание и защита': 1,
#  'Общественный транспорт': 2,
#  'Здравоохранение/Медицина': 3,
#  'Мусор/Свалки/ТКО': 4,
#  'Образование': 5,
#  'Дороги': 6,
#  'ЖКХ': 7,
#  'Коронавирус': 8,
#  'Экономика и бизнес': 9,
#  'Культура': 10,
#  'Связь и телевидение': 11,
#  'Газ и топливо': 12,
#  'Безопасность': 13,
#  'Спецпроекты': 14,
#  'Мобилизация': 15,
#  'МФЦ "Мои документы"': 16,
#  'Физическая культура и спорт': 17,
#  'Торговля': 18,
#  'Строительство и архитектура': 19,
#  'Памятники и объекты культурного наследия': 20,
#  'Экология': 21,
#  'Государственная собственность': 22,
#  'Роспотребнадзор': 23,
#  'Погребение и похоронное дело': 24,
#  'Электроснабжение': 25}

# %%
topic_group_dataset = data[['text', 'topic_group']]

# %%
topic_group_dataset.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                        text  \
# 0                                        'Добрый день. Сегодня, 20.08.22, моя мать шла по улице Ленина между домами 96 и 94. Фонари не горят, упала в яму, которую не видно. Сильно ударилась, остались синяки, очень больно. Благо шла не одна.<br>Уважаемая Администрация, сделайте с этим что-нибудь, да и не только с этим. Ходить опасно не только взрослым, но и детям. Если бы упал маленький ребёнок, было бы намного хуже. Фото прилагаю. Спасибо!
# 1                                                                                                                                                                                           'Пермь г, +79194692145. В Перми с ноября 2021 года не работает социальное такси. Каким образом можно получить льготу по проезду в такси в соц учреждения инвалиду 2гр.пррезд в общественном транспорте не возможен. Да и проездного льготного не представляется
# 2                                                                                                                                                                                                                                                                                                                      'Добрый день ! Скажите пожалуйста если подовала на пособие с 3 до 7 2 декабря , когда можно повторно подать ? вроде за 30 дней можно
# 3  'Каждая из них не о чем. Люди на остановках хотят укрыться от непогоды или слишком погоды. Присесть, поставить сумку. Лавочки на полторы попы? Отсутствие или намек на присутствие спинки? Конструкторы, понятно, что не ждут транспорт на остановках. А гаджеты заряжать дома надо. Интерактивные панели и близко не нужны. У каждого в руках телефоны- информации вагон. Разместить коды для быстрого доступа на ресурсы и сайты по транспорту хватит.
# 4                                                                                                                                                            'В Березниках у сына привитого откоронавируса заболел пытались попасть на прием очередь в замкнутом пространстве бесподобна прямое вредителбское отношение к людям он не смог попасть на прием что делать на работу с т - ой 37.8 не пускают и на прием не попасть .что вы мин здрав ДЕЛАЕТЕ ?
#
#                         topic_group
# 0                   Благоустройство
# 1  Социальное обслуживание и защита
# 2  Социальное обслуживание и защита
# 3            Общественный транспорт
# 4          Здравоохранение/Медицина

# %%
topic_group_dataset['topic_group'] = topic_group_dataset['topic_group'].map(topic_group_with_nums)
# Out:
# C:\Users\Chubu\AppData\Local\Temp\ipykernel_4704\2807714126.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   topic_group_dataset['topic_group'] = topic_group_dataset['topic_group'].map(topic_group_with_nums)

# %%
topic_group_dataset.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                        text  \
# 0                                        'Добрый день. Сегодня, 20.08.22, моя мать шла по улице Ленина между домами 96 и 94. Фонари не горят, упала в яму, которую не видно. Сильно ударилась, остались синяки, очень больно. Благо шла не одна.<br>Уважаемая Администрация, сделайте с этим что-нибудь, да и не только с этим. Ходить опасно не только взрослым, но и детям. Если бы упал маленький ребёнок, было бы намного хуже. Фото прилагаю. Спасибо!
# 1                                                                                                                                                                                           'Пермь г, +79194692145. В Перми с ноября 2021 года не работает социальное такси. Каким образом можно получить льготу по проезду в такси в соц учреждения инвалиду 2гр.пррезд в общественном транспорте не возможен. Да и проездного льготного не представляется
# 2                                                                                                                                                                                                                                                                                                                      'Добрый день ! Скажите пожалуйста если подовала на пособие с 3 до 7 2 декабря , когда можно повторно подать ? вроде за 30 дней можно
# 3  'Каждая из них не о чем. Люди на остановках хотят укрыться от непогоды или слишком погоды. Присесть, поставить сумку. Лавочки на полторы попы? Отсутствие или намек на присутствие спинки? Конструкторы, понятно, что не ждут транспорт на остановках. А гаджеты заряжать дома надо. Интерактивные панели и близко не нужны. У каждого в руках телефоны- информации вагон. Разместить коды для быстрого доступа на ресурсы и сайты по транспорту хватит.
# 4                                                                                                                                                            'В Березниках у сына привитого откоронавируса заболел пытались попасть на прием очередь в замкнутом пространстве бесподобна прямое вредителбское отношение к людям он не смог попасть на прием что делать на работу с т - ой 37.8 не пускают и на прием не попасть .что вы мин здрав ДЕЛАЕТЕ ?
#
#    topic_group
# 0            0
# 1            1
# 2            1
# 3            2
# 4            3

# %%
Х = topic_group_dataset['text']
y = topic_group_dataset['topic_group']

X_train, X_rem, y_train, y_rem = train_test_split(Х ,y, train_size=0.8)
X_valid, X_test, y_valid, y_test = train_test_split(X_rem, y_rem, test_size=0.5)

train_data = pd.concat([X_train, y_train], axis=1)
valid_data = pd.concat([X_valid, y_valid], axis=1)
test_data = pd.concat([X_test, y_test], axis=1)

train_data.columns =['text', 'topic_group']
valid_data.columns =['text', 'topic_group']
test_data.columns =['text', 'topic_group']

train_data.to_csv(r"train.csv", sep='\t')
valid_data.to_csv(r"valid.csv", sep='\t')
test_data.to_csv(r"test.csv", sep='\t')

# %%
data.topic.nunique()
# Out:
# 195

# %%
data.executor.nunique()
# Out:
# 10
